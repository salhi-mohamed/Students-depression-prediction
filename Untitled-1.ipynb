# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
df=pd.read_csv('DATA.csv')
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %% [markdown]
# # Handling zeros

# %%
# Count the number of zeros in each numerical feature
zeros_count = (numerical_features == 0).sum()

print("Number of zeros in each feature:")
print(zeros_count)
# Out:
# Number of zeros in each feature:
# id                        0
# Age                       0
# Academic Pressure         9
# Work Pressure         27898
# CGPA                      9
# Study Satisfaction       10
# Job Satisfaction      27893
# Work/Study Hours       1700
# Financial Stress          0
# Depression            11565
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Academic Pressure'], bins=10, kde=True, color='blue')
plt.title('Distribution of Academic Pressure', fontsize=16)
plt.xlabel('Academic Pressure', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Drop rows with 0 in academic pressure

# %%
# Count the initial number of rows
initial_row_count = df.shape[0]

# Drop rows where 'Academic Pressure' is 0
df = df[df['Academic Pressure'] != 0]

# Count the final number of rows
final_row_count = df.shape[0]

# Calculate the number of rows dropped
rows_dropped = initial_row_count - final_row_count

print(f"Number of rows dropped: {rows_dropped}")
# Out:
# Number of rows dropped: 9

# %% [markdown]
# ### Dropping work pressure and job satisfaction feature (all zeros)

# %%
df.drop(columns=['Work Pressure'], inplace=True)
df.drop(columns=['Job Satisfaction'], inplace=True)

# %% [markdown]
# ### No need to process the other features, as having a value of 0 in them is valid.

# %% [markdown]
# # Handling missing data

# %%
# Calculate the number of missing data in each column
missing_data_count = df.isnull().sum()

print("Number of missing data in each column:")
print(missing_data_count)
# Out:
# Number of missing data in each column:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# CGPA                                     0
# Study Satisfaction                       0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
# Count the initial number of rows
initial_row_count = df.shape[0]

# Drop rows with missing data in the 'Financial Stress' column
df = df.dropna(subset=['Financial Stress'])

# Count the final number of rows
final_row_count = df.shape[0]

# Calculate the number of rows dropped
rows_dropped = initial_row_count - final_row_count

print(f"Number of rows dropped: {rows_dropped}")
# Out:
# Number of rows dropped: 3

# %% [markdown]
# # Relation between features

# %% [markdown]
# ## Corrélations

# %%
numeric_features = df.select_dtypes(include=['number'])

# Matrice de corrélation Pearson
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_features.corr(method='pearson'), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matrice de corrélation (Pearson)")
plt.show()

# Matrice de corrélation Spearman
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_features.corr(method='spearman'), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matrice de corrélation (Spearman)")
plt.show()

# %%
# Filter rows where Depression equals 1
depression_data = df[df['Depression'] == 1]

# Group by Academic Pressure and count the occurrences
depression_counts = depression_data['Academic Pressure'].value_counts().sort_index()

print(depression_counts)
# Out:
# Academic Pressure
# 1.0     932
# 2.0    1566
# 3.0    4488
# 4.0    3925
# 5.0    5420
# Name: count, dtype: int64

# %%
depression_count_filtered1 = df[(df['Academic Pressure'] >= 3.0) & (df['Depression'] == 1)].shape[0]
depression_count_filtered2 = df[(df['Academic Pressure'] < 3.0) & (df['Depression'] == 1)].shape[0]
depression_count_filtered3 = df[(df['Academic Pressure'] < 3.0) & (df['Depression'] == 0)].shape[0]
depression_count_filtered4 = df[(df['Academic Pressure'] >= 3.0) & (df['Depression'] == 0)].shape[0]

print(f"Number of rows where Academic Pressure >= 3.0 and Depression = 1: {depression_count_filtered1}")
print(f"Number of rows where Academic Pressure < 3.0 and Depression = 1: {depression_count_filtered2}")
print(f"Number of rows where Academic Pressure < 3.0 and Depression = 0: {depression_count_filtered3}")
print(f"Number of rows where Academic Pressure >= 3.0 and Depression = 0: {depression_count_filtered4}")
# Out:
# Number of rows where Academic Pressure >= 3.0 and Depression = 1: 13833
# Number of rows where Academic Pressure < 3.0 and Depression = 1: 2498
# Number of rows where Academic Pressure < 3.0 and Depression = 0: 6479
# Number of rows where Academic Pressure >= 3.0 and Depression = 0: 5079

# %%
# Data for visualization
categories = ['Academic Pressure >= 3.0 & Depression = 1', 'Academic Pressure >= 3.0 & Depression = 0']
values = [depression_count_filtered1, depression_zero_count_above_or_equal_3]

# Plotting the bar chart
plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['blue', 'orange'])
plt.title('Comparison of Depression Status for Academic Pressure >= 3.0', fontsize=14)
plt.ylabel('Number of Students', fontsize=12)
plt.xlabel('Categories', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Consider graphic below in feature engineering
